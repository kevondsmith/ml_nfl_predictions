# %%
import nfl_data_py as nfl 
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt

df = []

# nfl.import_seasonal_data([2007, 2008])
schedules = nfl.import_schedules([2007, 2008])


# weekly_data = nfl.import_weekly_data([2019, 2020], ['player_name', 'recent_team', 'season', 'week',
#        'season_type', 'completions', 'attempts', 'passing_yards',
#        'passing_tds', 'interceptions', 'sacks',
#        'carries', 'rushing_yards', 'rushing_tds',
#        'receptions', 'targets', 'receiving_yards',
#        'receiving_tds', 'fantasy_points'])
# print(schedules)
data = pd.DataFrame(schedules)
data.head()
data.columns


categories = ['season', 'game_type', 'week', 'gameday', 'weekday',
       'gametime', 'away_team', 'away_score', 'home_team', 'home_score',
       'result', 'total', 'total_line', 'temp', 'stadium']

data_radar = data[['game_id'] + categories]
data_radar.head()

data_radar.to_csv('./data/schedules/2007-2008_games_schedules.csv')

# %%
import nfl_data_py as nfl 
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt


# nfl.import_seasonal_data([2007, 2008])
schedules = nfl.import_schedules([2009, 2010])


# weekly_data = nfl.import_weekly_data([2019, 2020], ['player_name', 'recent_team', 'season', 'week',
#        'season_type', 'completions', 'attempts', 'passing_yards',
#        'passing_tds', 'interceptions', 'sacks',
#        'carries', 'rushing_yards', 'rushing_tds',
#        'receptions', 'targets', 'receiving_yards',
#        'receiving_tds', 'fantasy_points'])
# print(schedules)
data = pd.DataFrame(schedules)
data.head()
data.columns


categories = ['season', 'game_type', 'week', 'gameday', 'weekday',
       'gametime', 'away_team', 'away_score', 'home_team', 'home_score',
       'result', 'total', 'total_line', 'temp', 'stadium']

data_radar = data[['game_id'] + categories]
data_radar.head()

data_radar.to_csv('./data/schedules/2009-2010_games_schedules.csv')

# %%
import nfl_data_py as nfl 
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt


# nfl.import_seasonal_data([2007, 2008])
schedules = nfl.import_schedules([2012, 2013])


# weekly_data = nfl.import_weekly_data([2019, 2020], ['player_name', 'recent_team', 'season', 'week',
#        'season_type', 'completions', 'attempts', 'passing_yards',
#        'passing_tds', 'interceptions', 'sacks',
#        'carries', 'rushing_yards', 'rushing_tds',
#        'receptions', 'targets', 'receiving_yards',
#        'receiving_tds', 'fantasy_points'])
# print(schedules)
data = pd.DataFrame(schedules)
data.head()
data.columns


categories = ['season', 'game_type', 'week', 'gameday', 'weekday',
       'gametime', 'away_team', 'away_score', 'home_team', 'home_score',
       'result', 'total', 'total_line', 'temp', 'stadium']

data_radar = data[['game_id'] + categories]
data_radar.head()

data_radar.to_csv('./data/schedules/2012-2013_games_schedules.csv')

# %%
import nfl_data_py as nfl 
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt


# nfl.import_seasonal_data([2007, 2008])
schedules = nfl.import_schedules([2015, 2016])


# weekly_data = nfl.import_weekly_data([2019, 2020], ['player_name', 'recent_team', 'season', 'week',
#        'season_type', 'completions', 'attempts', 'passing_yards',
#        'passing_tds', 'interceptions', 'sacks',
#        'carries', 'rushing_yards', 'rushing_tds',
#        'receptions', 'targets', 'receiving_yards',
#        'receiving_tds', 'fantasy_points'])
# print(schedules)
data = pd.DataFrame(schedules)
data.head()
data.columns


categories = ['season', 'game_type', 'week', 'gameday', 'weekday',
       'gametime', 'away_team', 'away_score', 'home_team', 'home_score',
       'result', 'total', 'total_line', 'temp', 'stadium']

data_radar = data[['game_id'] + categories]
data_radar.head()

data_radar.to_csv('./data/schedules/2015-2016_games_schedules.csv')

# %%
import nfl_data_py as nfl 
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt


# nfl.import_seasonal_data([2007, 2008])
schedules = nfl.import_schedules([2016, 2017])


# weekly_data = nfl.import_weekly_data([2019, 2020], ['player_name', 'recent_team', 'season', 'week',
#        'season_type', 'completions', 'attempts', 'passing_yards',
#        'passing_tds', 'interceptions', 'sacks',
#        'carries', 'rushing_yards', 'rushing_tds',
#        'receptions', 'targets', 'receiving_yards',
#        'receiving_tds', 'fantasy_points'])
# print(schedules)
data = pd.DataFrame(schedules)
data.head()
data.columns

categories = ['season', 'game_type', 'week', 'gameday', 'weekday',
       'gametime', 'away_team', 'away_score', 'home_team', 'home_score',
       'result', 'total', 'total_line', 'temp', 'stadium']

data_radar = data[['game_id'] + categories]
data_radar.head()

data_radar.to_csv('./data/schedules/2016-2017_games_schedules.csv')

# %%
import nfl_data_py as nfl 
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt


# nfl.import_seasonal_data([2007, 2008])
schedules = nfl.import_schedules([2019, 2020])


# weekly_data = nfl.import_weekly_data([2019, 2020], ['player_name', 'recent_team', 'season', 'week',
#        'season_type', 'completions', 'attempts', 'passing_yards',
#        'passing_tds', 'interceptions', 'sacks',
#        'carries', 'rushing_yards', 'rushing_tds',
#        'receptions', 'targets', 'receiving_yards',
#        'receiving_tds', 'fantasy_points'])
# print(schedules)
data = pd.DataFrame(schedules)
data.head()
data.columns

categories = ['season', 'game_type', 'week', 'gameday', 'weekday',
       'gametime', 'away_team', 'away_score', 'home_team', 'home_score',
       'result', 'total', 'total_line', 'temp', 'stadium']

data_radar = data[['game_id'] + categories]
data_radar.head()

data_radar.to_csv('./data/schedules/2019-2020_games_schedules.csv')

# %%
import nfl_data_py as nfl 
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt


# nfl.import_seasonal_data([2007, 2008])
schedules = nfl.import_schedules([2020, 2021])


# weekly_data = nfl.import_weekly_data([2019, 2020], ['player_name', 'recent_team', 'season', 'week',
#        'season_type', 'completions', 'attempts', 'passing_yards',
#        'passing_tds', 'interceptions', 'sacks',
#        'carries', 'rushing_yards', 'rushing_tds',
#        'receptions', 'targets', 'receiving_yards',
#        'receiving_tds', 'fantasy_points'])
# print(schedules)
data = pd.DataFrame(schedules)
data.head()
data.columns

categories = ['season', 'game_type', 'week', 'gameday', 'weekday',
       'gametime', 'away_team', 'away_score', 'home_team', 'home_score',
       'result', 'total', 'total_line', 'temp', 'stadium']

data_radar = data[['game_id'] + categories]
data_radar.head()

data_radar.to_csv('./data/schedules/2020-2021_games_schedules.csv')
